# %%
def es_paquete_valido(paquete):
    if len(paquete) != 10:
        return False
    for pieza in paquete:  #dentro de 1324567899 hacemos otro bucle.
        if pieza not in "1234":
            return False
    return True

def clasificar_porcentaje(porcentaje):
    if porcentaje < 50:
        return "Ligero"
    elif 50 <= porcentaje <= 60:
        return "Pesado"
    else:
        return "Muy pesado"
